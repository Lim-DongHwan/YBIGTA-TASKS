# %% [markdown]
# # REST API 실습
#
# 22th DE 김원

# %% [markdown]
# ## Python에서

# %%
import requests
# GET 요청 보내기
response = requests.get('https://reqres.in/api/users?page=2')

# 응답 확인
if response.status_code == 200:
    res = response.json()
    print(res)
else:
    print('요청에 실패했습니다. 상태 코드:', res.status_code)
# Out:
# {'page': 2, 'per_page': 6, 'total': 12, 'total_pages': 2, 'data': [{'id': 7, 'email': 'michael.lawson@reqres.in', 'first_name': 'Michael', 'last_name': 'Lawson', 'avatar': 'https://reqres.in/img/faces/7-image.jpg'}, {'id': 8, 'email': 'lindsay.ferguson@reqres.in', 'first_name': 'Lindsay', 'last_name': 'Ferguson', 'avatar': 'https://reqres.in/img/faces/8-image.jpg'}, {'id': 9, 'email': 'tobias.funke@reqres.in', 'first_name': 'Tobias', 'last_name': 'Funke', 'avatar': 'https://reqres.in/img/faces/9-image.jpg'}, {'id': 10, 'email': 'byron.fields@reqres.in', 'first_name': 'Byron', 'last_name': 'Fields', 'avatar': 'https://reqres.in/img/faces/10-image.jpg'}, {'id': 11, 'email': 'george.edwards@reqres.in', 'first_name': 'George', 'last_name': 'Edwards', 'avatar': 'https://reqres.in/img/faces/11-image.jpg'}, {'id': 12, 'email': 'rachel.howell@reqres.in', 'first_name': 'Rachel', 'last_name': 'Howell', 'avatar': 'https://reqres.in/img/faces/12-image.jpg'}], 'support': {'url': 'https://reqres.in/#support-heading', 'text': 'To keep ReqRes free, contributions towards server costs are appreciated!'}}

# %%
res
# Out:
# {'page': 2,
#  'per_page': 6,
#  'total': 12,
#  'total_pages': 2,
#  'data': [{'id': 7,
#    'email': 'michael.lawson@reqres.in',
#    'first_name': 'Michael',
#    'last_name': 'Lawson',
#    'avatar': 'https://reqres.in/img/faces/7-image.jpg'},
#   {'id': 8,
#    'email': 'lindsay.ferguson@reqres.in',
#    'first_name': 'Lindsay',
#    'last_name': 'Ferguson',
#    'avatar': 'https://reqres.in/img/faces/8-image.jpg'},
#   {'id': 9,
#    'email': 'tobias.funke@reqres.in',
#    'first_name': 'Tobias',
#    'last_name': 'Funke',
#    'avatar': 'https://reqres.in/img/faces/9-image.jpg'},
#   {'id': 10,
#    'email': 'byron.fields@reqres.in',
#    'first_name': 'Byron',
#    'last_name': 'Fields',
#    'avatar': 'https://reqres.in/img/faces/10-image.jpg'},
#   {'id': 11,
#    'email': 'george.edwards@reqres.in',
#    'first_name': 'George',
#    'last_name': 'Edwards',
#    'avatar': 'https://reqres.in/img/faces/11-image.jpg'},
#   {'id': 12,
#    'email': 'rachel.howell@reqres.in',
#    'first_name': 'Rachel',
#    'last_name': 'Howell',
#    'avatar': 'https://reqres.in/img/faces/12-image.jpg'}],
#  'support': {'url': 'https://reqres.in/#support-heading',
#   'text': 'To keep ReqRes free, contributions towards server costs are appreciated!'}}

# %%
res['data'][0]
# Out:
# {'id': 7,
#  'email': 'michael.lawson@reqres.in',
#  'first_name': 'Michael',
#  'last_name': 'Lawson',
#  'avatar': 'https://reqres.in/img/faces/7-image.jpg'}

# %%
import pandas as pd
df = pd.DataFrame(res['data'])
df
# Out:
#    id                       email first_name last_name  \
# 0   7    michael.lawson@reqres.in    Michael    Lawson
# 1   8  lindsay.ferguson@reqres.in    Lindsay  Ferguson
# 2   9      tobias.funke@reqres.in     Tobias     Funke
# 3  10      byron.fields@reqres.in      Byron    Fields
# 4  11    george.edwards@reqres.in     George   Edwards
# 5  12     rachel.howell@reqres.in     Rachel    Howell
#
#                                      avatar
# 0   https://reqres.in/img/faces/7-image.jpg
# 1   https://reqres.in/img/faces/8-image.jpg
# 2   https://reqres.in/img/faces/9-image.jpg
# 3  https://reqres.in/img/faces/10-image.jpg
# 4  https://reqres.in/img/faces/11-image.jpg
# 5  https://reqres.in/img/faces/12-image.jpg

# %% [markdown]
# ## terminal에서

# %% [markdown]
# 가장 간단한 요청입니다 curl + 요청을 보낼 주소 위는 코랩이기 때문에 터미널명령어를 !앞에 붙여 실행합니다 터미널에서는 !안붙여도 괜찮아요!!

# %%
# !curl https://reqres.in/api/users?page=2
# Out:
# {"page":2,"per_page":6,"total":12,"total_pages":2,"data":[{"id":7,"email":"michael.lawson@reqres.in","first_name":"Michael","last_name":"Lawson","avatar":"https://reqres.in/img/faces/7-image.jpg"},{"id":8,"email":"lindsay.ferguson@reqres.in","first_name":"Lindsay","last_name":"Ferguson","avatar":"https://reqres.in/img/faces/8-image.jpg"},{"id":9,"email":"tobias.funke@reqres.in","first_name":"Tobias","last_name":"Funke","avatar":"https://reqres.in/img/faces/9-image.jpg"},{"id":10,"email":"byron.fields@reqres.in","first_name":"Byron","last_name":"Fields","avatar":"https://reqres.in/img/faces/10-image.jpg"},{"id":11,"email":"george.edwards@reqres.in","first_name":"George","last_name":"Edwards","avatar":"https://reqres.in/img/faces/11-image.jpg"},{"id":12,"email":"rachel.howell@reqres.in","first_name":"Rachel","last_name":"Howell","avatar":"https://reqres.in/img/faces/12-image.jpg"}],"support":{"url":"https://reqres.in/#support-heading","text":"To keep ReqRes free, contributions towards server costs are appreciated!"}}

# %% [markdown]
# Curl에 여러가지 옵션을 추가할 수 있습니다
#
# -X : HTTP 메서드 지정
# <br>
#
# GET: 리소스를 가져오기 위한 요청입니다. 기본적으로 curl이 사용하는 메서드입니다.<br>
# POST: 리소스를 생성하기 위한 요청입니다. 데이터를 서버로 전송할 때 사용됩니다.<br>
# PUT: 리소스를 수정하기 위한 요청입니다. 전체 리소스를 업데이트합니다.<br>
# PATCH: 리소스를 일부 수정하기 위한 요청입니다. 부분적인 업데이트를 수행할 때 사용됩니다.<br>
# DELETE: 리소스를 삭제하기 위한 요청입니다.
#
# <br>
#
# -H : header 설정 header란 무엇일까? - 범위를 벗어나므로 신원을 확인하거나, 추가적인 정보가 담겨있는 부분: <br> => 메타데이터가 담겨있는 부분입니다!  <br>
#
# -d : data의 약자로 데이터를 넘겨줍니다
#
#
# <br>
#
# 아래의 예시의 경우, 게시판 홈페이지에 사람을 추가하는 예시! <br>
#
# 리소스를 생성하기 때문에 POST method로, 추가해야할 데이터를 -d 인자로 넘겨줍니다

# %%
# !curl -X POST -H "Content-Type: application/json" -d '{"name": "John", "age":30}' https://reqres.in/api/users
# Out:
# {"name":"John","age":30,"id":"750","createdAt":"2023-07-11T12:02:51.728Z"}

# %% [markdown]
# 위 코드를 실행하면, 정상응답이 나오는 경우 reqres.in 페이지에 /api/users에 새로운 유저를 등록 요청하는 request입니다!

# %% [markdown]
# ### 위를 파이썬 버전으로

# %%
import requests
import json

url = 'https://reqres.in/api/users'
headers = {'Content-Type': 'application/json'}
data = {'name': 'John', 'age': 30}


# post method로 요청

response = requests.post(url, headers=headers, data=json.dumps(data))

if response.status_code == 201: # 상태코드가 201이라면(201 : 요청 정상처리 상태코드 )
    result = response.json()
    print('사용자 생성 완료:', result)
else:
    print('요청에 실패했습니다. 상태 코드:', response.status_code)
# Out:
# 사용자 생성 완료: {'name': 'John', 'age': 30, 'id': '637', 'createdAt': '2023-07-11T12:03:59.443Z'}

# %%
res['data'][0]
# Out:
# {'id': 7,
#  'email': 'michael.lawson@reqres.in',
#  'first_name': 'Michael',
#  'last_name': 'Lawson',
#  'avatar': 'https://reqres.in/img/faces/7-image.jpg'}

# %% [markdown]
# # 페이지를 순회하며 데이터 프레임 만들기! + 약간의 전처리

# %%
import requests
# GET 요청 보내기
response = requests.get('https://reqres.in/api/users?page=2')

# 응답 확인
if response.status_code == 200:
    res = response.json()
    print(res)
else:
    print('요청에 실패했습니다. 상태 코드:', res.status_code)

# %% [markdown]
# # 원래 여러분들이 사용하실 때는...
#
# 보통 API의 호출양이 지정되어 있어서, API 세션 아이디, 키가 보통 필요해요!
#
# </br>
#
# 밑에 하고자 했던 코드는 여러페이지에 걸쳐 순회해서 데이터프레임으로 만드는 과정을 보여드리려고했는데,
# 저게 api가 연습용 서버여서 조금 호출 횟수에 제한된 것 같네요!! 원래 1페이지 부터 11페이지까지 6 x 11 행이 나와야하는데, 무료이다보니 서버에 부담이 되어 time.sleep(5)로 해봤는데도 안되네요! 하여튼 예시로 참고하면 좋을 것 같습니다!

# %%
import requests
import pandas as pd
import time

# 빈 데이터프레임 생성
df_combined = pd.DataFrame()

# 페이지 순회
for page in range(1, 11):
    # GET 요청 보내기
    url = f'https://reqres.in/api/users?page={page}'
    response = requests.get(url)

    # 응답 확인
    if response.status_code == 200:
        data = response.json()
        users = data['data']

        # 데이터프레임으로 변환
        df = pd.DataFrame(users)

        # 데이터프레임 결합
        df_combined = pd.concat([df_combined, df], ignore_index=True)
    else:
        print(f'페이지 {page} 요청에 실패했습니다. 상태 코드:', response.status_code)

# 합쳐진 데이터프레임 출력 (아쉽게도 안됨)
df_combined
# Out:
#     id                       email first_name last_name  \
# 0    1      george.bluth@reqres.in     George     Bluth
# 1    2      janet.weaver@reqres.in      Janet    Weaver
# 2    3         emma.wong@reqres.in       Emma      Wong
# 3    4          eve.holt@reqres.in        Eve      Holt
# 4    5    charles.morris@reqres.in    Charles    Morris
# 5    6      tracey.ramos@reqres.in     Tracey     Ramos
# 6    7    michael.lawson@reqres.in    Michael    Lawson
# 7    8  lindsay.ferguson@reqres.in    Lindsay  Ferguson
# 8    9      tobias.funke@reqres.in     Tobias     Funke
# 9   10      byron.fields@reqres.in      Byron    Fields
# 10  11    george.edwards@reqres.in     George   Edwards
# 11  12     rachel.howell@reqres.in     Rachel    Howell
#
#                                       avatar
# 0    https://reqres.in/img/faces/1-image.jpg
# 1    https://reqres.in/img/faces/2-image.jpg
# 2    https://reqres.in/img/faces/3-image.jpg
# 3    https://reqres.in/img/faces/4-image.jpg
# 4    https://reqres.in/img/faces/5-image.jpg
# 5    https://reqres.in/img/faces/6-image.jpg
# 6    https://reqres.in/img/faces/7-image.jpg
# 7    https://reqres.in/img/faces/8-image.jpg
# 8    https://reqres.in/img/faces/9-image.jpg
# 9   https://reqres.in/img/faces/10-image.jpg
# 10  https://reqres.in/img/faces/11-image.jpg
# 11  https://reqres.in/img/faces/12-image.jpg

# %% [markdown]
# # 과제 !! 나쁜 사람 아닙니다
#
#
# **개념 요약!! 아래 마크다운을 채워주세요 !! **
#
# 챗지피티 사용금지

# %% [markdown]
# ## API란 -> Application Programming Interface의 준말로, 서버 간 데이터 형식의 정보를 주고받기 위해서 사용하는 메시지 프로토콜
#
# ## REST API란 -> REST는 API의 디자인 프로토콜 중 하나로, 특정 resource에 대한 원하는 연산 방식을 할당시켜 요청을 보내는 일련의 관습적인 규칙
#
# ## 각각에 대응하는 HTTP의 메서드를 적어주세요
#
# ### Create -> POST
# ### Read -> GET
# ### Update -> PATCH
# ### Delete -> DELETE

# %% [markdown]
# ## 실습 과제 1 공식문서를 읽고 아래의 예시코드에 파라미터를 바꿔서 보낸 결과 확인하기!!
#
# 공식문서에 파라미터들을 직접 넘겨줘서 요청을 보내면 됩니다!

# %% [markdown]
# <https://punkapi.com/documentation/v2>

# %%
# !curl https://api.punkapi.com/v2/beers
# Out:
# [{"id":1,"name":"Buzz","tagline":"A Real Bitter Experience.","first_brewed":"09/2007","description":"A light, crisp and bitter IPA brewed with English and American hops. A small batch brewed only once.","image_url":"https://images.punkapi.com/v2/keg.png","abv":4.5,"ibu":60,"target_fg":1010,"target_og":1044,"ebc":20,"srm":10,"ph":4.4,"attenuation_level":75,"volume":{"value":20,"unit":"litres"},"boil_volume":{"value":25,"unit":"litres"},"method":{"mash_temp":[{"temp":{"value":64,"unit":"celsius"},"duration":75}],"fermentation":{"temp":{"value":19,"unit":"celsius"}},"twist":null},"ingredients":{"malt":[{"name":"Maris Otter Extra Pale","amount":{"value":3.3,"unit":"kilograms"}},{"name":"Caramalt","amount":{"value":0.2,"unit":"kilograms"}},{"name":"Munich","amount":{"value":0.4,"unit":"kilograms"}}],"hops":[{"name":"Fuggles","amount":{"value":25,"unit":"grams"},"add":"start","attribute":"bitter"},{"name":"First Gold","amount":{"value":25,"unit":"grams"},"add":"start","attribute":"bitter"},{"name":"Fuggles","amount":{"value":37.5,"unit":"grams"},"add":"middle","attribute":"flavour"},{"name":"First Gold","amount":{"value":37.5,"unit":"grams"},"add":"middle","attribute":"flavour"},{"name":"Cascade","amount":{"value":37.5,"unit":"grams"},"add":"end","attribute":"flavour"}],"yeast":"Wyeast 1056 - American Ale™"},"food_pairing":["Spicy chicken tikka masala","Grilled chicken quesadilla","Caramel toffee cake"],"brewers_tips":"The earthy and floral aromas from the hops can be overpowering. Drop a little Cascade in at the end of the boil to lift the profile with a bit of citrus.","contributed_by":"Sam Mason <samjbmason>"},{"id":2,"name":"Trashy Blonde","tagline":"You Know You Shouldn't","first_brewed":"04/2008","description":"A titillating, neurotic, peroxide punk of a Pale Ale. Combining attitude, style, substance, and a little bit of low self esteem for good measure; what would your mother say? The seductive lure of the sassy passion fruit hop proves too much to resist. All that is even before we get onto the fact that there are no additives, preservatives, pasteurization or strings attached. All wrapped up with the customary BrewDog bite and imaginative twist.","image_url":"https://images.punkapi.com/v2/2.png","abv":4.1,"ibu":41.5,"target_fg":1010,"target_og":1041.7,"ebc":15,"srm":15,"ph":4.4,"attenuation_level":76,"volume":{"value":20,"unit":"litres"},"boil_volume":{"value":25,"unit":"litres"},"method":{"mash_temp":[{"temp":{"value":69,"unit":"celsius"},"duration":null}],"fermentation":{"temp":{"value":18,"unit":"celsius"}},"twist":null},"ingredients":{"malt":[{"name":"Maris Otter Extra Pale","amount":{"value":3.25,"unit":"kilograms"}},{"name":"Caramalt","amount":{"value":0.2,"unit":"kilograms"}},{"name":"Munich","amount":{"value":0.4,"unit":"kilograms"}}],"hops":[{"name":"Amarillo","amount":{"value":13.8,"unit":"grams"},"add":"start","attribute":"bitter"},{"name":"Simcoe","amount":{"value":13.8,"unit":"grams"},"add":"start","attribute":"bitter"},{"name":"Amarillo","amount":{"value":26.3,"unit":"grams"},"add":"end","attribute":"flavour"},{"name":"Motueka","amount":{"value":18.8,"unit":"grams"},"add":"end","attribute":"flavour"}],"yeast":"Wyeast 1056 - American Ale™"},"food_pairing":["Fresh crab with lemon","Garlic butter dipping sauce","Goats cheese salad","Creamy lemon bar doused in powdered sugar"],"brewers_tips":"Be careful not to collect too much wort from the mash. Once the sugars are all washed out there are some very unpleasant grainy tasting compounds that can be extracted into the wort.","contributed_by":"Sam Mason <samjbmason>"},{"id":3,"name":"Berliner Weisse With Yuzu - B-Sides","tagline":"Japanese Citrus Berliner Weisse.","first_brewed":"11/2015","description":"Japanese citrus fruit intensifies the sour nature of this German classic.","image_url":"https://images.punkapi.com/v2/keg.png","abv":4.2,"ibu":8,"target_fg":1007,"target_og":1040,"ebc":8,"srm":4,"ph":3.2,"attenuation_level":83,"volume":{"value":20,"unit":"litres"},"bo ...

# %% [markdown]
# ```
# response = requests.get('https://reqres.in/api/users?page=2&per_page=10')
# response.get(url,params= {'page': 2, 'per_page':10 })
# ```
#
#
#
# 위에 두개는 같은 요청입니다! 뒤에 파라미터들이 ?으로 , 파라미터가 여러개일 경우 &으로 연결됩니다!

# %%
import requests
import json
import time

url = 'https://api.punkapi.com/v2/beers'
headers = {'Content-Type': 'application/json'}
# 파라미터로 인자 넘겨줄 수 있음!!
# 아래 params 코드에 인자들을 공식문서를 확인하여 추가하시거나 바꿔주세요!!
params= {'page': 2, 'per_page':10, 'abv_gt' : 7, 'brewed_after' : '01-2015', 'ibu_gt' : 50}

response = requests.get(url, headers=headers,params=params)

if response.status_code == 200:
    result = response.json()
    print('받아온 데이터:', result)
else:
    print('요청에 실패했습니다. 상태 코드:', response.status_code)
# Out:
# 받아온 데이터: [{'id': 208, 'name': 'Sunshine On Rye - B-Sides', 'tagline': 'Hoppy Rye IPA.', 'first_brewed': '02/2015', 'description': 'A Pilot Brew "Sunshine on Rye" uses loads of spicy malt and coriander to play nice with an inhuman amount of hops!', 'image_url': 'https://images.punkapi.com/v2/keg.png', 'abv': 7.2, 'ibu': 130, 'target_fg': 1010, 'target_og': 1065, 'ebc': 14, 'srm': 7, 'ph': 5.2, 'attenuation_level': 87, 'volume': {'value': 20, 'unit': 'litres'}, 'boil_volume': {'value': 25, 'unit': 'litres'}, 'method': {'mash_temp': [{'temp': {'value': 60, 'unit': 'celsius'}, 'duration': 10}, {'temp': {'value': 65, 'unit': 'celsius'}, 'duration': 30}, {'temp': {'value': 72, 'unit': 'celsius'}, 'duration': 10}, {'temp': {'value': 78, 'unit': 'celsius'}, 'duration': 5}], 'fermentation': {'temp': {'value': 20, 'unit': 'celsius'}}, 'twist': 'Indian Coriander: 2.5g'}, 'ingredients': {'malt': [{'name': 'Extra Pale', 'amount': {'value': 5, 'unit': 'kilograms'}}, {'name': 'Rye', 'amount': {'value': 0.63, 'unit': 'kilograms'}}, {'name': 'Caramalt', 'amount': {'value': 0.25, 'unit': 'kilograms'}}], 'hops': [{'name': 'Amarillo', 'amount': {'value': 17.5, 'unit': 'grams'}, 'add': 'start', 'attribute': 'bitter'}, {'name': 'Citra', 'amount': {'value': 17.5, 'unit': 'grams'}, 'add': 'start', 'attribute': 'bitter'}, {'name': 'Simcoe', 'amount': {'value': 17.5, 'unit': 'grams'}, 'add': 'start', 'attribute': 'bitter'}, {'name': 'Amarillo', 'amount': {'value': 17.5, 'unit': 'grams'}, 'add': 'middle', 'attribute': 'flavour'}, {'name': 'Citra', 'amount': {'value': 17.5, 'unit': 'grams'}, 'add': 'middle', 'attribute': 'flavour'}, {'name': 'Simcoe', 'amount': {'value': 17.5, 'unit': 'grams'}, 'add': 'middle', 'attribute': 'flavour'}, {'name': 'Amarillo', 'amount': {'value': 17.5, 'unit': 'grams'}, 'add': 'end', 'attribute': 'aroma'}, {'name': 'Citra', 'amount': {'value': 17.5, 'unit': 'grams'}, 'add': 'end', 'attribute': 'flavour'}, {'name': 'Simcoe', 'amount': {'value': 17.5, 'unit': 'grams'}, 'add': 'end', 'attribute': 'aroma'}, {'name': 'Nelson Sauvin', 'amount': {'value': 22.5, 'unit': 'grams'}, 'add': 'end', 'attribute': 'aroma'}], 'yeast': 'Wyeast 1056 - American Ale™'}, 'food_pairing': ['Jerk spiced goat', 'Tonkotsu Ramen', 'Gingerbread'], 'brewers_tips': 'Indian coriander accentuates the citrus character from the hops. Use fresh spices to really accentuate this relationship.', 'contributed_by': 'Sam Mason <samjbmason>'}, {'id': 216, 'name': 'Barrel Aged Hinterland', 'tagline': 'A Most Beguiling Brew. Aged In Bourbon Casks.', 'first_brewed': '06/2016', 'description': 'Hinterland is a beer long in the creation, and even longer in the appreciation. On the aroma, deep reverberating roasty bitterness and sweet dark chocolate. Also in evidence, woodsmoke, rich vanilla, mocha and marzipan. When tasting, Hinterland reveals itself as the beer moves from cellar temperature to something warmer, yielding all of the above plus dried fruit, rich ganache and ending on a resoundingly warming  nish redolent of chocolate liqueur or plum brandy. Aged in Bourbon Casks.', 'image_url': 'https://images.punkapi.com/v2/216.png', 'abv': 9, 'ibu': 85, 'target_fg': 1025, 'target_og': 1094, 'ebc': 400, 'srm': 200, 'ph': 4.3, 'attenuation_level': 73.4, 'volume': {'value': 20, 'unit': 'litres'}, 'boil_volume': {'value': 25, 'unit': 'litres'}, 'method': {'mash_temp': [{'temp': {'value': 65, 'unit': 'celsius'}, 'duration': None}], 'fermentation': {'temp': {'value': 21, 'unit': 'celsius'}}, 'twist': 'Lactose (Milk Sugar): 500g at middle'}, 'ingredients': {'malt': [{'name': 'Pale Ale', 'amount': {'value': 6.88, 'unit': 'kilograms'}}, {'name': 'Wheat', 'amount': {'value': 0.5, 'unit': 'kilograms'}}, {'name': 'Flaked Oats', 'amount': {'value': 1, 'unit': 'kilograms'}}, {'name': 'Dark Crystal', 'amount': {'value': 0.5, 'unit': 'kilograms'}}, {'name': 'Carafa Special Malt Type 1', 'amount': {'value': 0.75, 'unit': 'kilograms'}}, {'name': 'Chocolate', 'amount': {'value': 1, 'unit': ' ...

# %%
import pandas as pd

df = pd.DataFrame(result)
df
# Out:
#     id                               name  \
# 0  208          Sunshine On Rye - B-Sides
# 1  216             Barrel Aged Hinterland
# 2  217  Barrel Aged Albino Squid Assassin
# 3  218                        Monk Hammer
# 4  219                         Ship Wreck
# 5  222                              Dog E
# 6  225                  Paradox Islay 2.0
# 7  226                       Chili Hammer
# 8  229                         Rye Hammer
# 9  230                       Black Hammer
#
#                                          tagline first_brewed  \
# 0                                 Hoppy Rye IPA.      02/2015
# 1  A Most Beguiling Brew. Aged In Bourbon Casks.      06/2016
# 2           Red Rye IPA Aged In Rye Whisky Cask.      06/2016
# 3         Our Ruthless IPA With A Belgian Twist.      03/2016
# 4                    Redacted Collaboration Ale.      03/2016
# 5              Ninth Anniversary Imperial Stout.      06/2016
# 6                Islay Cask-Aged Imperial Stout.      06/2016
# 7           Our Ruthless IPA With A Fiery Twist.      06/2016
# 8           Our Ruthless IPA with A Spicy Twist.      06/2016
# 9       Our Ruthless IPA With A Dark Malt Twist.      06/2016
#
#                                          description  \
# 0  A Pilot Brew "Sunshine on Rye" uses loads of s...
# 1  Hinterland is a beer long in the creation, and...
# 2  This tentacled terminator packs a punch - ten ...
# 3  Jack Hammer has been single handedly ripping i...
# 4  This mezcal-inspired brew is the shipwrecked r...
# 5  Dog E is a very special beer. This beer commem...
# 6  Intense peaty smoke layers on decadent roast c...
# 7  Chili Hammer is the third of our super-charged...
# 8  Rye Hammer is the fourth of our super-charged ...
# 9  Jack Hammer has been single handedly ripping i...
#
#                                image_url   abv  ibu  target_fg  target_og  \
# 0  https://images.punkapi.com/v2/keg.png   7.2  130       1010       1065
# 1  https://images.punkapi.com/v2/216.png   9.0   85       1025       1094
# 2  https://images.punkapi.com/v2/217.png   9.2   65       1012       1069
# 3  https://images.punkapi.com/v2/218.png   7.2  250       1010       1065
# 4  https://images.punkapi.com/v2/219.png  13.8   60       1015       1088
# 5  https://images.punkapi.com/v2/222.png  16.1  100       1125       1015
# 6  https://images.punkapi.com/v2/225.png  13.0  100       1112       1015
# 7  https://images.punkapi.com/v2/226.png   7.2  250       1010       1065
# 8  https://images.punkapi.com/v2/229.png   7.2  250       1010       1065
# 9  https://images.punkapi.com/v2/230.png   7.2  250       1010       1065
#
#    ...    srm   ph  attenuation_level                           volume  \
# 0  ...    7.0  5.2               87.0  {'value': 20, 'unit': 'litres'}
# 1  ...  200.0  4.3               73.4  {'value': 20, 'unit': 'litres'}
# 2  ...   30.0  4.2               82.6  {'value': 20, 'unit': 'litres'}
# 3  ...    7.5  4.4               84.6  {'value': 20, 'unit': 'litres'}
# 4  ...   13.0  4.4               83.0  {'value': 20, 'unit': 'litres'}
# 5  ...  254.0  4.4               84.0  {'value': 20, 'unit': 'litres'}
# 6  ...  152.0  4.4               84.4  {'value': 20, 'unit': 'litres'}
# 7  ...    7.5  4.4               84.6  {'value': 20, 'unit': 'litres'}
# 8  ...    8.5  4.4               84.6  {'value': 20, 'unit': 'litres'}
# 9  ...   53.0  4.4               84.6  {'value': 20, 'unit': 'litres'}
#
#                        boil_volume  \
# 0  {'value': 25, 'unit': 'litres'}
# 1  {'value': 25, 'unit': 'litres'}
# 2  {'value': 25, 'unit': 'litres'}
# 3  {'value': 25, 'unit': 'litres'}
# 4  {'value': 25, 'unit': 'litres'}
# 5  {'value': 25, 'unit': 'litres'}
# 6  {'value': 25, 'unit': 'litres'}
# 7  {'value': 25, 'unit': 'litres'}
# 8  {'value': 25, 'unit': 'litres'}
# 9  {'value': 25, 'unit': 'litres'}
#
#                                               method  \
# 0  {'mash_temp': [{'temp': {'value': 60, 'unit': ...
# 1  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 2  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 3  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 4  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 5  {'mash_temp': [{'temp': {'value': 63, 'unit': ...
# 6  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 7  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 8  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 9  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
#
#                                          ingredients  \
# 0  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 1  {'malt': [{'name': 'Pale Ale', 'amount': {'val...
# 2  {'malt': [{'name': 'Pale Ale', 'amount': {'val...
# 3  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 4  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 5  {'malt': [{'name': 'Pale Ale', 'amount': {'val...
# 6  {'malt': [{'name': 'Pale Ale', 'amount': {'val...
# 7  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 8  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 9  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
#
#                                         food_pairing  \
# 0    [Jerk spiced goat, Tonkotsu Ramen, Gingerbread]
# 1  [Mulled cheddar buffalo burger, Venison with w...
# 2  [Rocket and mozzarella salad with a cracked pe...
# 3  [Pesto chicken pizza, Beer braised Brussels sp...
# 4  [Shrimp aguachile, Mezcal marinated sirloin st...
# 5  [Char sui pork buns, Spicy beef empanadas, Cho...
# 6  [Smoked mackerel & radish salad, Ossobuco, Dar...
# 7  [Aubergine and chickpea tagine, Firehouse chil...
# 8  [Smoked salmon tostada, Schäufele, Rye apple ...
# 9  [Buffalo wings with blue cheese dip, Spinach a...
#
#                                         brewers_tips          contributed_by
# 0  Indian coriander accentuates the citrus charac...  Sam Mason <samjbmason>
# 1  Towards the end of the fermentation allow the ...  Sam Mason <samjbmason>
# 2  20% specialty malts in this grist can create p...  Sam Mason <samjbmason>
# 3  Oxygen is critical for this strain of yeast so...  Sam Mason <samjbmason>
# 4  Nail your colours to the mother fucking mast –...  Sam Mason <samjbmason>
# 5  With stronger styles (like imperial stouts), f...  Sam Mason <samjbmason>
# 6  Get a whisky barrel to add the extra depth to ...  Sam Mason <samjbmason>
# 7  There are a multitude of chilies you can exper...  Sam Mason <samjbmason>
# 8  The amount of rye shouldn’t cause a stuck mash...  Sam Mason <samjbmason>
# 9  You may have to leave this beer on dry hops fo...  Sam Mason <samjbmason>
#
# [10 rows x 21 columns]

# %% [markdown]
# ## 과제 2 컨퍼런스 혹은 신입기수 세션에서 데이터를 끌어올 수 있는 API를 찾아보시고 찾기!
#
#
#
# - response 응답의 구조를 파악하여 어떤 열을 어떻게 활용할 수 있을지 적어보세요!
#
# - 찾은 API 명세서 -> 활용방안을 적어주시면 됩니다!

# %% [markdown]
# 추천 :
#
# 요즘은 다른 거를 가져다가 쓰는 게 또 능력이죠
#
# ### <https://www.reddit.com/dev/api/>
#
# ### <https://developers.kakao.com/>
#
# ### <https://developers.naver.com/main/>
#
# ### <https://platform.openai.com/docs/introduction>

# %% [markdown]
# # 아래 작성해주시면 됩니다!!

# %% [markdown]
# ### 사용할 API : https://scienceon.kisti.re.kr/apigateway/api/main/mainForm.do - 한국과학기술정보연구원(KISTI)에서 제공하는 논문, 특허, 보고서 등의 학술 자료를 REST API 기반 gateway의 형태로 개방하는 오픈서비스
#
#
# ### 사용할 기능또는 api 응답에서 제공되는 변수 :
# 1. 논문 / 특허 / 보고서 검색 : 저널 및 프로시딩에 수록된 논문, 특허, 보고서 등을 XML 형태의 출력 결과로 검색. 'searchQuery' 파라미터를 이용해 검색 대상 필드 및 검색어를 입력하고, 'rowCount' 파라미터로 출력 논문의 개수를 조정하는 식으로 변수값을 조정할 수 있음
# 2. 연구 동향 및 연구자, 지식인프라 검색 : 같은 메커니즘으로, 각 연구 분야 별 해외 / 국내 연구 동향에 대한 최근 뉴스 및 전문 기사들을 검색하거나, 특정 저서 및 논문의 저자, 특정 연구 분야 내 연구자, 특정 지식 인프라에서 주최하는 교육 및 컨퍼런스에 대한 정보까지 조사 가능
#
# ### 활용 방안 : 학회 내에서 이루어지는 스터디, 컨퍼런스 준비, 공모전 준비 등 어떤 상황에서든 탐구 주제로 삼는 분야나 논문, 혹은 연구자에 대한 추가 정보가 필요한 상황이 심심치 않게 생길 수 있을 것 같다. 최근 타 학회 내 프로젝트를 진행하면서, 참고 자료로 사용한 논문과 학술 자료의 저자에게 직접 관련 내용에 대해 물어보고 싶은 경우가 종종 생겼었는데, 대상 저자가 항상 연락을 받을 수 있는 상황인 것이 아니기에 소통을 시도하는 것에 어려움을 느꼈던 경험이 있다. 그럴 때 2번째 기능을 십분 활용하여 관련 연구 동향에 대해 다룬 타 연구 자료에서 정보를 얻거나, 그 분야의 지식 인프라에서 얻을 수 있는 정보가 무엇이 있는지 쉽게 알아볼 수 있을 것 같다.

# %% [markdown]
# # 출처
#
# - 내머리
# - 챗지피티
